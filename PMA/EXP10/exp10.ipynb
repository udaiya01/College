# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

np.random.seed(0)

x = np.random.rand(100, 5)*10

y = 2.5 * x[:,  0] + 1.5 * x[:, 1] + 0.5 * x[:, 2] + np.random.randn(100) * 2

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

model = LinearRegression()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")

print (f"R-squared (R²): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 4.52
# R-squared (R²): 0.95

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load data from CSV file
data = pd.read_csv('/content/data10.csv')  # Replace 'your_data.csv' with your file path

# Assuming the first 5 columns are features and the last column is the target
x = data[['feature1', 'feature2', 'feature3', 'feature4', 'feature5']].values
y = data['target'].values

# Train-Test Split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Initialize the model
model = LinearRegression()

# Train the model
model.fit(x_train, y_train)

# Predict
y_pred = model.predict(x_test)

# Calculate MSE and R²
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Output results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 537.44
# R-squared (R²): -63.93

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load data from a URL
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQM0leG1mAFTDtf3MlcYPhU_o-RJ7YvArpyksDMeWbzdrq3HRDBiNZETZ8HshVTZHz1H7IN7pS8Hrpk/pub?output=csv'  # Replace this with your actual URL
data = pd.read_csv(url)

# Assuming the first 5 columns are features and the last column is the target
x = data[['feature1', 'feature2', 'feature3', 'feature4', 'feature5']].values
y = data['target'].values

# Train-Test Split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Initialize the model
model = LinearRegression()

# Train the model
model.fit(x_train, y_train)

# Predict
y_pred = model.predict(x_test)

# Calculate MSE and R²
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Output results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")
# Out:
#                             UDAIYANETHI 221191101141
# Mean Squared Error (MSE): 537.44
# R-squared (R²): -63.93
