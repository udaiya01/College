# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = load_iris()
X = pd.DataFrame(df.data, columns=df.feature_names)
y = pd.Series(df.target)

# Initialize and fit RFE
model = RandomForestClassifier()
rfe = RFE(estimator=model, n_features_to_select=2)
rfe.fit(X, y)

# Create feature importance dataframe
ranking = rfe.ranking_
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Ranking': ranking
}).sort_values(by='Ranking')

print(feature_importance)

# Plotting
sns.barplot(x='Ranking', y='Feature', data=feature_importance)
plt.title('Feature Importance Ranking')
sns.despine()
plt.show()
# Out:
#              Feature  Ranking
# 2  petal length (cm)        1
# 3   petal width (cm)        1
# 0  sepal length (cm)        2
# 1   sepal width (cm)        3

# %%
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from CSV
data = pd.read_csv(r'/content/iris.csv')
X = data.drop(columns='target')  # 'target' is the column name for the target variable
y = data['target']

# Initialize and fit RFE
model = RandomForestClassifier()
rfe = RFE(estimator=model, n_features_to_select=2)
rfe.fit(X, y)

# Create feature importance dataframe
ranking = rfe.ranking_
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Ranking': ranking
}).sort_values(by='Ranking')

# Plotting
sns.barplot(x='Ranking', y='Feature', data=feature_importance)
plt.title('Feature Importance Ranking UDAIYANETHI_1141')
sns.despine()
plt.show()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-b36388364c7b>", line 8, in <cell line: 8>
#     data = pd.read_csv(r'/content/iris.csv')
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 1880, in _make_engine
# ...

# %%
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQFXsD3Gbw4MicmefSWbDO0-M2OSMxiU4jHIQczCqtsmaCqp_Q-q_n21XfCoMyWySJt5uiekkBhCBO-/pub?output=csv'
data = pd.read_csv(url)

X = data.drop(columns='target')  # 'target' is the column name for the target variable
y = data['target']

# Initialize and fit RFE
model = RandomForestClassifier()
rfe = RFE(estimator=model, n_features_to_select=2)
rfe.fit(X, y)

# Create feature importance dataframe
ranking = rfe.ranking_
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Ranking': ranking
}).sort_values(by='Ranking')

# Plotting
sns.barplot(x='Ranking', y='Feature', data=feature_importance)
plt.title('Feature Importance Ranking UDAIYANETHI_1141')
sns.despine()
plt.show()

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier


# Load Iris data
data = pd.read_csv(url)
X = data.drop(columns='target')  # 'target' is the column name for the target variable
y = data['target']

data = load_iris()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target)

# Perform RFE (selecting top 2 features)
rfe = RFE(RandomForestClassifier(), n_features_to_select=2)
rfe.fit(X, y)

# Create a DataFrame with feature names and their ranking
feature_ranking = pd.DataFrame({'Feature': X.columns, 'Ranking': rfe.ranking_}).sort_values(by='Ranking')

print(feature_ranking)
# Out:
#              Feature  Ranking
# 2  petal length (cm)        1
# 3   petal width (cm)        1
# 0  sepal length (cm)        2
# 1   sepal width (cm)        3
