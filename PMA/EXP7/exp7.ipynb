# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import seaborn as sns
# Load the Iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# Range of K values to test
k_values = range(1, 21)

mean_scores = []

# Loop over different values of K
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X, y, cv=5, scoring='accuracy')
    mean_scores.append(scores.mean())

# Plotting the results
plt.plot(k_values, mean_scores, marker='o')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Cross-Validated Accuracy')
plt.title('KNN Accuracy vs. K')
sns.despine()
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset from CSV
df = pd.read_csv('/content/iris.csv')

# Separate features and target
X = df.drop('target', axis=1)
y = df['target']

# Range of K values to test
k_values = range(1, 21)

mean_scores = []

# Loop over different values of K
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X, y, cv=5, scoring='accuracy')
    mean_scores.append(scores.mean())

# Plotting the results
plt.plot(k_values, mean_scores, marker='o')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Cross-Validated Accuracy')
plt.title('KNN Accuracy vs. K UDAIYANETHI_1141
')
sns.despine()
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQFXsD3Gbw4MicmefSWbDO0-M2OSMxiU4jHIQczCqtsmaCqp_Q-q_n21XfCoMyWySJt5uiekkBhCBO-/pub?output=csv'
df = pd.read_csv(url)

# Separate features and target
X = df.drop('target', axis=1)
y = df['target']

# Range of K values to test
k_values = range(1, 21)

mean_scores = []

# Loop over different values of K
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X, y, cv=5, scoring='accuracy')
    mean_scores.append(scores.mean())

# Plotting the results
plt.plot(k_values, mean_scores, marker='o')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Cross-Validated Accuracy')
plt.title('KNN Accuracy vs. K UDAIYANETHI_1141')
sns.despine()
plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

# Load the Iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# Range of K values to test
k_values = range(1, 21)
mean_scores = []

# Loop over different values of K
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X, y, cv=5, scoring='accuracy')
    mean_scores.append(scores.mean())

# Display results
for k, score in zip(k_values, mean_scores):
    print(f"K = {k}: Cross-Validated Accuracy = {score:.2f}")
# Out:
# K = 1: Cross-Validated Accuracy = 0.96
# K = 2: Cross-Validated Accuracy = 0.95
# K = 3: Cross-Validated Accuracy = 0.97
# K = 4: Cross-Validated Accuracy = 0.97
# K = 5: Cross-Validated Accuracy = 0.97
# K = 6: Cross-Validated Accuracy = 0.98
# K = 7: Cross-Validated Accuracy = 0.98
# K = 8: Cross-Validated Accuracy = 0.97
# K = 9: Cross-Validated Accuracy = 0.97
# K = 10: Cross-Validated Accuracy = 0.98
# K = 11: Cross-Validated Accuracy = 0.98
# K = 12: Cross-Validated Accuracy = 0.98
# K = 13: Cross-Validated Accuracy = 0.97
# K = 14: Cross-Validated Accuracy = 0.97
# K = 15: Cross-Validated Accuracy = 0.97
# K = 16: Cross-Validated Accuracy = 0.97
# K = 17: Cross-Validated Accuracy = 0.97
# K = 18: Cross-Validated Accuracy = 0.97
# K = 19: Cross-Validated Accuracy = 0.97
# K = 20: Cross-Validated Accuracy = 0.96
