# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Set random seed for reproducibility
np.random.seed(0)

# Generate random data
x = np.random.rand(100, 1) * 10  # 100 random values in range [0, 10]
y = 2.5 * x.flatten() + np.random.randn(100) * 2  # Linear relationship with noise

# Split data into training and testing sets (70% train, 30% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Initialize and train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)

# Predict values for the test set
y_pred = model.predict(x_test)

# Calculate Mean Squared Error (MSE) and R-squared (R²) for model evaluation
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print evaluation metrics
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 3.12
# R-squared (R²): 0.92

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

text = "UDAIYANETHI 221191101141"
width = 80  # You can adjust the width according to your terminal
print(text.center(width))

# Load data from a CSV file
# Replace 'data.csv' with the path to your CSV file
data = pd.read_csv('/content/data9.csv')

# Assume the CSV has two columns named 'X' and 'Y'
x = data[['X']].values  # Independent variable
y = data['Y'].values     # Dependent variable

# Split data into training and testing sets (70% train, 30% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Initialize and train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)

# Predict values for the test set
y_pred = model.predict(x_test)

# Calculate Mean Squared Error (MSE) and R-squared (R²) for model evaluation
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print evaluation metrics
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")

plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color='blue', label='Actual values', alpha=0.6)
plt.scatter(x_test, y_pred, color='red', label='Predicted values', alpha=0.6)
plt.plot(x_test, y_pred, color='green', label='Regression line', linewidth=2)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Linear Regression Prediction UDAIYANETHI 221191101141')
plt.legend()
plt.grid(True)
sns.despine()
plt.show()
# Out:
# Mean Squared Error (MSE): 0.00
# R-squared (R²): 1.00

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

text = "UDAIYANETHI 221191101141"
width = 80  # You can adjust the width according to your terminal
print(text.center(width))

# Load data from a CSV file URL
# Replace 'your_csv_url_here' with the actual URL to your CSV file
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQ1uHZEyYSCBej9DwGGB6G1OklprIq9c-7r0ptJ4POAjcBatQkFeRymb1c8PlGd0_SJPWy58K4DTed1/pub?output=csv'  # e.g., 'https://example.com/data.csv'
data = pd.read_csv(url)

# Assume the CSV has two columns named 'X' and 'Y'
x = data[['X']].values  # Independent variable
y = data['Y'].values     # Dependent variable

# Split data into training and testing sets (70% train, 30% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Initialize and train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)

# Predict values for the test set
y_pred = model.predict(x_test)

# Calculate Mean Squared Error (MSE) and R-squared (R²) for model evaluation
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print evaluation metrics
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")

plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color='blue', label='Actual values', alpha=0.6)
plt.scatter(x_test, y_pred, color='red', label='Predicted values', alpha=0.6)
plt.plot(x_test, y_pred, color='green', label='Regression line', linewidth=2)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Linear Regression Prediction UDAIYANETHI 221191101141')
plt.legend()
plt.grid(True)
sns.despine()
plt.show()
# Out:
#                             UDAIYANETHI 221191101141
# Mean Squared Error (MSE): 0.00
# R-squared (R²): 1.00

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Sample dataset as a DataFrame
data = pd.DataFrame({
    'X': [1, 2, 3, 4, 5],
    'Y': [2.5, 5, 7.5, 10, 12.5]
})

# Check for missing values
print(data.info())

# Prepare data
x = data[['X']].values
y = data['Y'].values

# Split data into training and testing sets (70% train, 30% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Initialize and train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)

# Predict values for the test set
y_pred = model.predict(x_test)

# Print predicted values to debug
print("Predicted values:", y_pred)

# Calculate Mean Squared Error (MSE) and R-squared (R²) for model evaluation
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print evaluation metrics
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")

# Plotting the results
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color='blue', label='Actual values', alpha=0.6)
plt.scatter(x_test, y_pred, color='red', label='Predicted values', alpha=0.6)
plt.plot(x_test, y_pred, color='green', label='Regression line', linewidth=2)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Linear Regression Prediction')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       5 non-null      int64
#  1   Y       5 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 208.0 bytes
# None
# Predicted values: [ 5.  12.5]
# Mean Squared Error (MSE): 0.00
# R-squared (R²): 1.00

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
# Sample data
data = pd.DataFrame({'X': [1, 2, 3, 4, 5], 'Y': [2.5, 5, 7.5, 10, 12.5]})
# Prepare data
X = data[['X']]
y = data['Y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Train model
model = LinearRegression().fit(X_train, y_train)
# Predict and evaluate
y_pred = model.predict(X_test)
# Calculate Mean Squared Error (MSE) and R-squared (R²) for model evaluation
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print evaluation metrics
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")

# Plot
plt.scatter(x_test, y_test, color='blue', label='Actual values')
plt.scatter(x_test, y_pred, color='red', label='Predicted values')
plt.plot(x_test, y_pred, color='green', label='Regression line', linewidth=2)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Linear Regression Prediction')
plt.legend()
plt.show()
# Out:
# MSE: 0.00, R²: 1.00
